# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
plt.rcParams['font.family']='AppleGothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 데이터 수집 및 전처리
# 행정안전부<br>
# https://www.mois.go.kr/<br>
# 정책자료>주민등록인구통계>연령별 인구현황<br>
# 성별구분하지않음, 1세단위, 0~100세이상, 전체읍면동 현황

# %%
df = pd.read_csv('../data/202205_202205_연령별인구현황_월간.csv',encoding='cp949')

# %%
df.head(3)
# Out:
#                           행정구역 2022년05월_계_총인구수 2022년05월_계_연령구간인구수  \
# 0          서울특별시  (1100000000)       9,496,887          9,496,887
# 1       서울특별시 종로구 (1111000000)         143,850            143,850
# 2  서울특별시 종로구 청운효자동(1111051500)          11,838             11,838
#
#   2022년05월_계_0세 2022년05월_계_1세 2022년05월_계_2세 2022년05월_계_3세 2022년05월_계_4세  \
# 0        41,979        44,804        46,533        50,108        53,563
# 1           459           471           542           549           603
# 2            46            45            54            54            57
#
#   2022년05월_계_5세 2022년05월_계_6세  ... 2022년05월_계_91세 2022년05월_계_92세  \
# 0        59,181        65,916  ...          7,896          6,592
# 1           703           821  ...            175            140
# 2            80            86  ...             13              7
#
#   2022년05월_계_93세 2022년05월_계_94세 2022년05월_계_95세 2022년05월_계_96세 2022년05월_계_97세  \
# 0          5,530          4,032          2,970          1,845          1,364
# 1            121             80             83             48             37
# 2              7              5              6              4              3
#
#   2022년05월_계_98세 2022년05월_계_99세 2022년05월_계_100세 이상
# 0          1,089            917              1,723
# 1             26             23                 40
# 2              4              1                  3
#
# [3 rows x 104 columns]

# %% [markdown]
# ## 컬럼삭제

# %%
df = df.drop(columns=['2022년05월_계_총인구수', '2022년05월_계_연령구간인구수'])

# %%
df
# Out:
#                               행정구역 2022년05월_계_0세 2022년05월_계_1세 2022년05월_계_2세  \
# 0              서울특별시  (1100000000)        41,979        44,804        46,533
# 1           서울특별시 종로구 (1111000000)           459           471           542
# 2      서울특별시 종로구 청운효자동(1111051500)            46            45            54
# 3        서울특별시 종로구 사직동(1111053000)            35            30            35
# 4        서울특별시 종로구 삼청동(1111054000)             2             7             4
# ...                            ...           ...           ...           ...
# 3861  제주특별자치도 서귀포시 서홍동(5013058000)            80            73            89
# 3862  제주특별자치도 서귀포시 대륜동(5013059000)           114           112           165
# 3863  제주특별자치도 서귀포시 대천동(5013060000)            91           108           122
# 3864  제주특별자치도 서귀포시 중문동(5013061000)            66            76            84
# 3865  제주특별자치도 서귀포시 예래동(5013062000)            16            13            13
#
#      2022년05월_계_3세 2022년05월_계_4세 2022년05월_계_5세 2022년05월_계_6세 2022년05월_계_7세  \
# 0           50,108        53,563        59,181        65,916        67,429
# 1              549           603           703           821           805
# 2               54            57            80            86            92
# 3               50            46            63            75            65
# 4                4            15             5            13            11
# ...            ...           ...           ...           ...           ...
# 3861           104           110           133           161           162
# 3862           149           143           185           158           188
# 3863           125           160           194           204           199
# 3864            92            84            85           122           114
# 3865            24            12            27            19            37
#
#      2022년05월_계_8세  ... 2022년05월_계_91세 2022년05월_계_92세 2022년05월_계_93세  \
# 0           66,338  ...          7,896          6,592          5,530
# 1              822  ...            175            140            121
# 2               96  ...             13              7              7
# 3               66  ...             16             14             15
# 4               14  ...              5              6              1
# ...            ...  ...            ...            ...            ...
# 3861           166  ...             11              5              8
# 3862           167  ...             14             12             10
# 3863           191  ...             12             15              3
# 3864           119  ...             14              9             11
# 3865            22  ...             10             10              3
#
#      2022년05월_계_94세 2022년05월_계_95세 2022년05월_계_96세 2022년05월_계_97세  \
# 0             4,032          2,970          1,845          1,364
# 1                80             83             48             37
# 2                 5              6              4              3
# 3                 3              7              8              5
# 4                 3              3              0              1
# ...             ...            ...            ...            ...
# 3861              6              0              2              0
# 3862              5              5              3              2
# 3863             10              4              4              0
# 3864              7              3              4              1
# 3865              4              4              1              0
#
#      2022년05월_계_98세 2022년05월_계_99세 2022년05월_계_100세 이상
# 0             1,089            917              1,723
# 1                26             23                 40
# 2                 4              1                  3
# 3                 2              3                  1
# 4                 1              2                  2
# ...             ...            ...                ...
# 3861              1              2                  3
# 3862              2              4                  7
# 3863              1              1                  4
# 3864              2              0                  3
# 3865              0              3                  1
#
# [3866 rows x 102 columns]

# %% [markdown]
# ## 익덱스 변경

# %%
df.index=df['행정구역']

# %%
df=df.drop(columns=['행정구역'])

# %% [markdown]
# ## 컬럼명 변경

# %%
df.columns = df.columns.str.split('_').str[2]

# %%
df.head(1)
# Out:
#                          0세      1세      2세      3세      4세      5세      6세  \
# 행정구역
# 서울특별시  (1100000000)  41,979  44,804  46,533  50,108  53,563  59,181  65,916
#
#                          7세      8세      9세  ...    91세    92세    93세    94세  \
# 행정구역                                         ...
# 서울특별시  (1100000000)  67,429  66,338  71,995  ...  7,896  6,592  5,530  4,032
#
#                        95세    96세    97세    98세  99세 100세 이상
# 행정구역
# 서울특별시  (1100000000)  2,970  1,845  1,364  1,089  917   1,723
#
# [1 rows x 101 columns]

# %% [markdown]
# ## 자료형 확인/변경

# %%
df.dtypes
# Out:
# 0세         object
# 1세         object
# 2세         object
# 3세         object
# 4세         object
#             ...
# 96세        object
# 97세        object
# 98세        object
# 99세        object
# 100세 이상    object
# Length: 101, dtype: object

# %%
for i in range(101):
    df.iloc[:,i]=df.iloc[:,i].str.replace(',','').astype('int64')

# %%
df.dtypes
# Out:
# 0세         int64
# 1세         int64
# 2세         int64
# 3세         int64
# 4세         int64
#            ...
# 96세        int64
# 97세        int64
# 98세        int64
# 99세        int64
# 100세 이상    int64
# Length: 101, dtype: object

# %% [markdown]
# # 시도-연령별 인구구조
# ## 서브셋 만들기
# - `컬럼.str.contains(문자열)` : 해당 문자열이 포함된 데이터 추출

# %%
df_sido = df[df.index.str.contains('00000000')]

# %% [markdown]
# ## 시각화
# ### 다중 플롯

# %%
df_sido.head(3)
# Out:
#                         0세     1세     2세     3세     4세     5세     6세     7세  \
# 행정구역
# 서울특별시  (1100000000)  41979  44804  46533  50108  53563  59181  65916  67429
# 부산광역시  (2600000000)  14073  14949  16568  18447  20752  23206  26158  26576
# 대구광역시  (2700000000)  10272  11082  12707  14026  15844  17991  19868  20377
#
#                         8세     9세  ...   91세   92세   93세   94세   95세   96세  \
# 행정구역                               ...
# 서울특별시  (1100000000)  66338  71995  ...  7896  6592  5530  4032  2970  1845
# 부산광역시  (2600000000)  25893  27605  ...  2961  2378  2064  1566   984   665
# 대구광역시  (2700000000)  19870  21548  ...  2120  1558  1245   960   640   410
#
#                       97세   98세  99세  100세 이상
# 행정구역
# 서울특별시  (1100000000)  1364  1089  917     1723
# 부산광역시  (2600000000)   471   318  270      434
# 대구광역시  (2700000000)   291   204  145      268
#
# [3 rows x 101 columns]

# %%
plt.rcParams['figure.figsize']=(12,5)
for i in range(len(df_sido)):
    plt.plot(df_sido.iloc[i], label=df_sido.index[i].split()[0])
plt.legend()
plt.xticks(range(0,101,5))
plt.xlabel('연령')
plt.ylabel('인구수')
plt.title('2022년 5월 시도-연령별 인구수', size=20)
plt.show()

# %% [markdown]
# ### 서브플롯
# - `plt.subplot(행,열,순번)`

# %%
fig = plt.figure(figsize=(20,30))
for i in range(len(df_sido)):
    plt.subplot(6,3,i+1)
    plt.plot(df_sido.iloc[i])
    plt.xticks(range(0,101,10))
    plt.title(df_sido.index[i].split()[0])
    plt.grid(ls=':')
fig.tight_layout()

# %% [markdown]
# # 서울시 구별 인구구조
# ## 서브셋 만들기

# %%
df_seoul = df[df.index.str.find('구 (11')>0]

# %% [markdown]
# ## 시각화
# ### 다중 플롯

# %%
for i in range(len(df_seoul)):
    plt.plot(df_seoul.iloc[i], label=df_seoul.index[i].split()[1])
plt.legend(ncol=2)
plt.xticks(range(0,101,10))
plt.title('2022년 5월 서울시 구별 연령별 인구구조', size=20)
plt.ylabel('인구수')
plt.show()

# %% [markdown]
# ### 서브플롯
# - `fig.add_subplot(행,열,순번)`

# %%
fig = plt.figure(figsize=(15,30))
for i in range(len(df_seoul)):
    ax = fig.add_subplot(9,3,i+1)
    ax.plot(df_seoul.iloc[i])
    ax.set_xticks(range(0,101,10))
    ax.set_yticks(range(0,15000,1000))
    ax.set_title(df_seoul.index[i].split()[1])
fig.tight_layout()

# %% [markdown]
# # 특정 동 인구구조
# ## 학군지 인구구조
# - 대치, 목
# - `fig, ax = plt.subplots()`

# %%
df_dong = df[(df.index.str.contains('강남구 대치')) | (df.index.str.contains('양천구 목'))].copy()
df_dong
# Out:
#                              0세   1세   2세   3세   4세   5세   6세   7세   8세   9세  \
# 행정구역
# 서울특별시 양천구 목1동(1147051000)    90  106  133  156  217  250  360  391  457  493
# 서울특별시 양천구 목2동(1147052000)   139  134  111  152  142  158  183  153  184  190
# 서울특별시 양천구 목3동(1147053000)   125  110  128  121  114  145  120  130  102  112
# 서울특별시 양천구 목4동(1147054000)    49   64   73   92   88  123  153  141  182  236
# 서울특별시 양천구 목5동(1147055000)    82  131  127  149  228  297  388  462  539  599
# 서울특별시 강남구 대치1동(1168060000)   33   39   54   79  114  160  211  253  318  391
# 서울특별시 강남구 대치2동(1168061000)   77  110  113  149  176  185  241  293  332  408
# 서울특별시 강남구 대치4동(1168063000)   33   38   48   52   39   73   74   77  112  101
#
#                             ...  91세  92세  93세  94세  95세  96세  97세  98세  99세  \
# 행정구역                        ...
# 서울특별시 양천구 목1동(1147051000)   ...   14   16   11    9    6    2    1    5    3
# 서울특별시 양천구 목2동(1147052000)   ...   13   20   12   11    3    6    2    1    2
# 서울특별시 양천구 목3동(1147053000)   ...   14   13   16   10    5    3    3    0    4
# 서울특별시 양천구 목4동(1147054000)   ...   14   16   14    6    3    1    3    2    3
# 서울특별시 양천구 목5동(1147055000)   ...   30   25   23   18   16   11    7    2    2
# 서울특별시 강남구 대치1동(1168060000)  ...   16   12    9    5    6    1    2    2    2
# 서울특별시 강남구 대치2동(1168061000)  ...   22   11   16    7    8    7    2    1    3
# 서울특별시 강남구 대치4동(1168063000)  ...    9   14    4    2    4    0    1    0    0
#
#                             100세 이상
# 행정구역
# 서울특별시 양천구 목1동(1147051000)         1
# 서울특별시 양천구 목2동(1147052000)         1
# 서울특별시 양천구 목3동(1147053000)         5
# 서울특별시 양천구 목4동(1147054000)         3
# 서울특별시 양천구 목5동(1147055000)         0
# 서울특별시 강남구 대치1동(1168060000)        6
# 서울특별시 강남구 대치2동(1168061000)        2
# 서울특별시 강남구 대치4동(1168063000)        2
#
# [8 rows x 101 columns]

# %%
fig, ax = plt.subplots(3,3, figsize=(15,10), sharey=True)

for i in range(len(df_dong)): 
    # 서브플롯의 행번호:r, 열번호:c    
    r, c = i//3, i%3
    ax[r][c].plot(df_dong.iloc[i])
    ax[r][c].set_xticks(range(0,101,10))
    ax[r][c].set_title(df_dong.index[i].split('(')[0])
    
fig.tight_layout()

# %% [markdown]
# ## 특정 구의 동별 인구구조

# %%
df_dong2 = df[df.index.str.contains('관악구')]
df_dong2
# Out:
#                               0세    1세    2세    3세    4세    5세    6세    7세  \
# 행정구역
# 서울특별시 관악구 (1162000000)      1521  1511  1655  1642  1784  2005  2156  2258
# 서울특별시 관악구 보라매동(1162052500)    71    65    86    97    96   113   132   143
# 서울특별시 관악구 청림동(1162054500)    110   116   112    95   109   134   123   106
# 서울특별시 관악구 성현동(1162056500)    111   136   148   134   152   178   207   233
# 서울특별시 관악구 행운동(1162057500)     82   100    86    90    96   107   104   111
# 서울특별시 관악구 낙성대동(1162058500)    41    40    51    37    58    65    58    70
# 서울특별시 관악구 청룡동(1162059500)    106    92   125   113   125   120   130   120
# 서울특별시 관악구 은천동(1162060500)    146   146   138   151   173   176   217   223
# 서울특별시 관악구 중앙동(1162061500)     38    25    29    39    33    42    35    49
# 서울특별시 관악구 인헌동(1162062500)     88    91   102    96    81    92   105   100
# 서울특별시 관악구 남현동(1162063000)     74    69    79    79    76    87   101    92
# 서울특별시 관악구 서원동(1162064500)     67    55    53    60    51    65    67    49
# 서울특별시 관악구 신원동(1162065500)     43    33    41    44    43    48    54    57
# 서울특별시 관악구 서림동(1162066500)     61    56    48    59    75    74    71    88
# 서울특별시 관악구 신사동(1162068500)     51    53    59    70    66    73    93    85
# 서울특별시 관악구 신림동(1162069500)     45    31    34    32    26    35    34    33
# 서울특별시 관악구 난향동(1162071500)     53    74    87    79   118   101   106   136
# 서울특별시 관악구 조원동(1162072500)     54    42    56    40    53    73    65    66
# 서울특별시 관악구 대학동(1162073500)     60    57    58    66    58    71    59    65
# 서울특별시 관악구 삼성동(1162074500)     38    44    61    47    68    82    86   107
# 서울특별시 관악구 미성동(1162076500)     99   108   113   129   136   157   187   189
# 서울특별시 관악구 난곡동(1162077500)     83    78    89    85    91   112   122   136
#
#                               8세    9세  ...  91세  92세  93세  94세  95세  96세  \
# 행정구역                                    ...
# 서울특별시 관악구 (1162000000)      2133  2351  ...  327  255  214  158  121   57
# 서울특별시 관악구 보라매동(1162052500)   120   121  ...   27   14   14   10    6    8
# 서울특별시 관악구 청림동(1162054500)    115   108  ...   17   14   11    5    2    0
# 서울특별시 관악구 성현동(1162056500)    219   262  ...   24   18   16    9    4    4
# 서울특별시 관악구 행운동(1162057500)    107   109  ...   22   10   15    5    3    2
# 서울특별시 관악구 낙성대동(1162058500)    77    81  ...    5    3    7    6    1    2
# 서울특별시 관악구 청룡동(1162059500)    103   128  ...   22   19    7    8    7    4
# 서울특별시 관악구 은천동(1162060500)    215   223  ...   17   21   18   12   11    3
# 서울특별시 관악구 중앙동(1162061500)     38    53  ...   11    4    4    2    2    2
# 서울특별시 관악구 인헌동(1162062500)     98   119  ...   15    7    3   10    8    6
# 서울특별시 관악구 남현동(1162063000)     88    75  ...   10    4   10    4    5    5
# 서울특별시 관악구 서원동(1162064500)     67    61  ...   10    9   11    2    5    2
# 서울특별시 관악구 신원동(1162065500)     56    73  ...   11   13    4    7    7    1
# 서울특별시 관악구 서림동(1162066500)     85    79  ...   11   10    8    9    9    2
# 서울특별시 관악구 신사동(1162068500)     78    82  ...   18    8    7    9    7    2
# 서울특별시 관악구 신림동(1162069500)     20    24  ...    6    6    2    3    7    2
# 서울특별시 관악구 난향동(1162071500)    132   146  ...    9    9    8    3    6    1
# 서울특별시 관악구 조원동(1162072500)     65    76  ...   10   13    7   10    1    2
# 서울특별시 관악구 대학동(1162073500)     63   102  ...   10   12    6   10    4    2
# 서울특별시 관악구 삼성동(1162074500)     83    94  ...   20   31   24   15   12    3
# 서울특별시 관악구 미성동(1162076500)    172   196  ...   34   12   18    5    7    1
# 서울특별시 관악구 난곡동(1162077500)    132   139  ...   18   18   14   14    7    3
#
#                             97세  98세  99세  100세 이상
# 행정구역
# 서울특별시 관악구 (1162000000)       53   45   41       73
# 서울특별시 관악구 보라매동(1162052500)    0    5    1        2
# 서울특별시 관악구 청림동(1162054500)     2    0    2        1
# 서울특별시 관악구 성현동(1162056500)     3    3    3        6
# 서울특별시 관악구 행운동(1162057500)     3    4    1        2
# 서울특별시 관악구 낙성대동(1162058500)    1    2    2        2
# 서울특별시 관악구 청룡동(1162059500)     4    1    3        1
# 서울특별시 관악구 은천동(1162060500)     5    4    2        3
# 서울특별시 관악구 중앙동(1162061500)     1    0    0        3
# 서울특별시 관악구 인헌동(1162062500)     2    2    3        3
# 서울특별시 관악구 남현동(1162063000)     4    2    1        4
# 서울특별시 관악구 서원동(1162064500)     3    0    0        3
# 서울특별시 관악구 신원동(1162065500)     5    3    3        7
# 서울특별시 관악구 서림동(1162066500)     5    2    0        7
# 서울특별시 관악구 신사동(1162068500)     3    1    1        4
# 서울특별시 관악구 신림동(1162069500)     1    1    0        3
# 서울특별시 관악구 난향동(1162071500)     1    2    1        0
# 서울특별시 관악구 조원동(1162072500)     1    0    1        2
# 서울특별시 관악구 대학동(1162073500)     1    2    2        1
# 서울특별시 관악구 삼성동(1162074500)     1    6    8        4
# 서울특별시 관악구 미성동(1162076500)     3    4    1        9
# 서울특별시 관악구 난곡동(1162077500)     4    1    6        6
#
# [22 rows x 101 columns]

# %%
fig, ax = plt.subplots(7,3, figsize=(15,15), sharey=True)

for i in range(1, len(df_dong2)): 
    # 서브플롯의 행번호:r, 열번호:c    
    r, c = (i-1)//3, (i-1)%3
    ax[r][c].plot(df_dong2.iloc[i])
    ax[r][c].set_xticks(range(0,101,10))
    ax[r][c].set_title(df_dong2.index[i].split('(')[0])
    
fig.tight_layout()
